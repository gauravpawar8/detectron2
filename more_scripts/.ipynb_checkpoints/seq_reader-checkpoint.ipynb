# %%
import exiftool

# %%
# files = ["/home/ubuntu/gfav/data/phase2/seq_files/DJI_0004.SEQ"]
# with exiftool.ExifTool() as et:
#     metadata = et.get_metadata_batch(files)

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
# cv2.VideoWriter_fourcc('X','V', 'I', 'D')
# cap = cv2.VideoCapture('/output/output/DJI_0004jpeg.avi')
cap = cv2.VideoCapture('/home/ubuntu/gfav/data/phase2/thermal_videos/DJI_0003.avi')

# %%
# cap.set('6', cv2.CAP_PROP_FOURCC('M','P', 'N', 'G'))

# %%
i = 0
while(cap.isOpened()):
    ret, frame = cap.read()
    if frame is None:
        break
#     print(frame.shape)
    break
    if i%30 == 0:
        plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
#         plt.imshow(frame)
        plt.show()
#     break
    i += 1
cap.release()

# %%
# %matplotlib notebook
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
# cv2.VideoWriter_fourcc('X','V', 'I', 'D')
# cap = cv2.VideoCapture('/output/output/DJI_0004jpeg.avi')
cap = cv2.VideoCapture('/output/output/DJI_0004.avi')

# %%
# %matplotlib notebook
while(cap.isOpened()):
    ret, frame = cap.read(cv2.IMREAD_UNCHANGED)
    if frame is None:
        print('nothing is there')
        break
    plt.imshow(frame)
    break
cap.release()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
# cv2.VideoWriter_fourcc('X','V', 'I', 'D')
# cap = cv2.VideoCapture('/output/output/DJI_0004jpeg.avi')
cap = cv2.VideoCapture('/output/output/DJI_0004jpeg.avi')

# %%
# %matplotlib notebook
while(cap.isOpened()):
    ret, frame = cap.read()
    if frame is None:
        print('nothing is there')
        break
    plt.imshow(frame)
    break
cap.release()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
# cv2.VideoWriter_fourcc('X','V', 'I', 'D')
# cap = cv2.VideoCapture('/output/output/DJI_0004jpeg.avi')
cap = cv2.VideoCapture('/output/output/DJI_0004tiff.avi', cv2.IMREAD_UNCHANGED)

# %%
# %matplotlib notebook
while(cap.isOpened()):
    ret, frame = cap.read()
    if frame is None:
        print('nothing is there')
        break
    plt.imshow(frame)
    break
cap.release()

# %%
pil_image = Image.open('/home/ubuntu/gfav/data/phase2/seq_files/temp/frame00453.tiff')
# im.show()
numpy_array = np.array(pil_image)

# %%
plt.imshow(numpy_array)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### read tiff frames

# %%
from PIL import Image
import numpy as np
import cv2
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
import os

# %%
tiff_list = os.listdir('/home/ubuntu/gfav/data/phase3/tiff_frames/DJI_3011_0/')
tiff_list.sort()

# %%
rgb_list = os.listdir('/home/ubuntu/gfav/data/phase3/rgb_frames_int/DJI_3011_0/')
rgb_list.sort()
# print(rgb_list)

# %%
# %matplotlib notebook
i = 0
for tiff_image_name in tiff_list:
    if tiff_image_name[-4:] != 'tiff':
        continue
    mat_image = plt.imread('/home/ubuntu/gfav/data/phase3/tiff_frames/DJI_3009_0/' + tiff_image_name)
    if i%90==0:
        plt.imshow(mat_image)
        plt.show()
    i += 1
    break
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### find range for tiff images

# %%
vmin = 10000
vmax = 0
vminlist = []
vmaxlist = []
dir_list = os.listdir('/home/ubuntu/gfav/data/phase3/tiff_frames/')
for dir_name in dir_list:
    vmin = 10000
    vmax = 0
    if dir_name[:3] != 'DJI':
        continue
    tiff_list = os.listdir('/home/ubuntu/gfav/data/phase3/tiff_frames/' + dir_name + '/')
    for tiff_image_name in tiff_list:
        if tiff_image_name[-4:] != 'tiff':
            continue
        tiff_image = plt.imread('/home/ubuntu/gfav/data/phase3/tiff_frames/' + dir_name + '/' + tiff_image_name)
        vminlist.append(tiff_image.min())
        vmaxlist.append(tiff_image.max())
        if tiff_image.min() < vmin:
            vmin = tiff_image.min()
        if tiff_image.max() > vmax:
            vmax = tiff_image.max()
    print(vmin, vmax, dir_name)
# Out:
# 2140 3886 DJI_3002_0
# 2054 3728 DJI_3007_0
# 2020 2514 DJI_3010_0
# 1939 2916 DJI_3009_0
# 2014 2520 DJI_3011_0
# 1964 3117 DJI_3005_0

# %%
plt.hist(vminlist, bins=20)
# Out:
# (array([  55.,  145.,  279.,  729., 2062., 1709., 2865., 3875., 5498.,
#         4579., 2258., 1450., 1172., 1294.,  691.,  907.,  322.,  159.,
#          297.,  174.]),
#  array([1939.  , 1956.45, 1973.9 , 1991.35, 2008.8 , 2026.25, 2043.7 ,
#         2061.15, 2078.6 , 2096.05, 2113.5 , 2130.95, 2148.4 , 2165.85,
#         2183.3 , 2200.75, 2218.2 , 2235.65, 2253.1 , 2270.55, 2288.  ]),
#  <a list of 20 Patch objects>)

# %%
xt = []
xtt = []
for i in range(2200, 3900, 100):
    xt.append(i)
for i in range(22, 39, 1):
    xtt.append(i)

# %%
plt.hist(vmaxlist, bins=17)
plt.xticks(xt, xtt)
# Out:
# ([<matplotlib.axis.XTick at 0x7f41906c3550>,
#   <matplotlib.axis.XTick at 0x7f41906d8240>,
#   <matplotlib.axis.XTick at 0x7f41906d89e8>,
#   <matplotlib.axis.XTick at 0x7f41905dd710>,
#   <matplotlib.axis.XTick at 0x7f41905ddcf8>,
#   <matplotlib.axis.XTick at 0x7f41905f1208>,
#   <matplotlib.axis.XTick at 0x7f41905f16d8>,
#   <matplotlib.axis.XTick at 0x7f41905f1ba8>,
#   <matplotlib.axis.XTick at 0x7f41905f8128>,
#   <matplotlib.axis.XTick at 0x7f41905f8588>,
#   <matplotlib.axis.XTick at 0x7f41905f8a58>,
#   <matplotlib.axis.XTick at 0x7f41905f8f28>,
#   <matplotlib.axis.XTick at 0x7f41905f8630>,
#   <matplotlib.axis.XTick at 0x7f41905f1b70>,
#   <matplotlib.axis.XTick at 0x7f41905dd908>,
#   <matplotlib.axis.XTick at 0x7f41905446d8>,
#   <matplotlib.axis.XTick at 0x7f4190544ba8>],
#  <a list of 17 Text xticklabel objects>)

# %%
vmin = 2000
vmax = 3100

# %% [markdown]
# ### apply color pallette to tiff images

# %%
vmin = 10000
vmax = 0
vminlist = []
vmaxlist = []
dir_list = os.listdir('/home/ubuntu/gfav/data/phase3/tiff_frames/')
for dir_name in dir_list:
    if dir_name!= 'DJI_3002_0':
        continue
    vmin = 10000
    vmax = 0
    if dir_name[:3] != 'DJI':
        continue
    tiff_list = os.listdir('/home/ubuntu/gfav/data/phase3/tiff_frames/' + dir_name + '/')
    for tiff_image_name in tiff_list:
        if tiff_image_name[-4:] != 'tiff':
            continue
        tiff_image = plt.imread('/home/ubuntu/gfav/data/phase3/tiff_frames/' + dir_name + '/' + tiff_image_name)
        vminlist.append(tiff_image.min())
        vmaxlist.append(tiff_image.max())
        if tiff_image.min() < vmin:
            vmin = tiff_image.min()
        if tiff_image.max() > vmax:
            vmax = tiff_image.max()
    print(vmin, vmax, dir_name)
# Out:
# 2140 3886 DJI_3002_0

# %%
histt = plt.hist(vminlist, bins=20)
thresh = 0.05 * np.sum(histt[0])
bins = 20
summ = 0
vmin = 0
for i in range(bins):
    summ += histt[0][i]
    if summ >= thresh:
        vmin = int(histt[1][i])
        print('vmin:', vmin)
        break
# Out:
# vmin: 2169

# %%
histt = plt.hist(vmaxlist, bins=20)
thresh = 0.05 * np.sum(histt[0])
bins = 20
summ = 0
vmax = 0
for i in range(bins-1, -1, -1):
    summ += histt[0][i]
    if summ >= thresh:
        vmax = int(histt[1][i])
        print('vmax:', vmax)
        break
# Out:
# vmax: 3049

# %%
dir_name = 'DJI_3002_0/'
tiff_list = os.listdir('/home/ubuntu/gfav/data/phase3/tiff_frames/' + dir_name)
tiff_list.sort()
rgb_list = os.listdir('/home/ubuntu/gfav/data/phase3/rgb_frames_int/' + dir_name)
rgb_list.sort()
# %matplotlib notebook
cmap = plt.cm.jet
for rgb_filename in rgb_list:
    if rgb_filename[-3:] !='jpg':
        continue
    rgb_image = cv2.imread('/home/ubuntu/gfav/data/phase3/rgb_frames_int/' + dir_name + rgb_filename)
    rgb_crop = rgb_image[426:1741, 1001:2776, :].copy()
    ind = int(rgb_filename[-9:-4])
    tiff_image = plt.imread('/home/ubuntu/gfav/data/phase3/tiff_frames/' + dir_name + 'frame' + \
                            format(int((90*ind + 1)/0.99), '05d') + '.tiff')
    print(tiff_image.min(), tiff_image.max())
    norm = plt.Normalize(vmin, vmax)
    tiff_image = cmap(norm(tiff_image))
#     tiff_image = cmap(tiff_image)
    # save the image
    plt.imsave('/home/ubuntu/gfav/data/phase3/ir_frames/' + dir_name + rgb_filename, tiff_image)
    ir_image = cv2.imread('/home/ubuntu/gfav/data/phase3/ir_frames/' + dir_name + rgb_filename)
    ir_resize = cv2.resize(ir_image, (rgb_crop.shape[1], rgb_crop.shape[0]))
    cv2.imwrite('/home/ubuntu/gfav/data/phase3/ir_frames/' + dir_name + rgb_filename, ir_resize)
    cv2.imwrite('/home/ubuntu/gfav/data/phase3/rgb_frames_crop/' + dir_name + rgb_filename, rgb_crop)
    figure(num=None, figsize=(8, 6), dpi=100, facecolor='w', edgecolor='k')
    plt.subplot(1, 2, 1)
    plt.imshow(cv2.cvtColor(rgb_crop, cv2.COLOR_BGR2RGB))
    plt.subplot(1, 2, 2)
    plt.imshow(cv2.cvtColor(ir_resize, cv2.COLOR_BGR2RGB))
    plt.show()

# %%
vmin = 10000
vmax = 0
vminlist = []
vmaxlist = []
dir_list = os.listdir('/home/ubuntu/gfav/data/phase3/tiff_frames/')
for dir_name in dir_list:
    if dir_name!= 'DJI_3005_0':
        continue
    vmin = 10000
    vmax = 0
    if dir_name[:3] != 'DJI':
        continue
    tiff_list = os.listdir('/home/ubuntu/gfav/data/phase3/tiff_frames/' + dir_name + '/')
    for tiff_image_name in tiff_list:
        if tiff_image_name[-4:] != 'tiff':
            continue
        tiff_image = plt.imread('/home/ubuntu/gfav/data/phase3/tiff_frames/' + dir_name + '/' + tiff_image_name)
        vminlist.append(tiff_image.min())
        vmaxlist.append(tiff_image.max())
        if tiff_image.min() < vmin:
            vmin = tiff_image.min()
        if tiff_image.max() > vmax:
            vmax = tiff_image.max()
    print(vmin, vmax, dir_name)
# Out:
# 1964 3117 DJI_3005_0

# %%
histt = plt.hist(vminlist, bins=20)
thresh = 0.05 * np.sum(histt[0])
bins = 20
summ = 0
vmin = 0
for i in range(bins):
    summ += histt[0][i]
    if summ >= thresh:
        vmin = int(histt[1][i])
        print('vmin:', vmin)
        break
# Out:
# vmin: 2063

# %%
histt = plt.hist(vmaxlist, bins=20)
thresh = 0.05 * np.sum(histt[0])
bins = 20
summ = 0
vmax = 0
for i in range(bins-1, -1, -1):
    summ += histt[0][i]
    if summ >= thresh:
        vmax = int(histt[1][i])
        print('vmax:', vmax)
        break
# Out:
# vmax: 2741

# %%
# # %matplotlib notebook
# dir_name = 'DJI_3005_0/'
# tiff_list = os.listdir('/home/ubuntu/gfav/data/phase3/tiff_frames/' + dir_name)
# tiff_list.sort()
# rgb_list = os.listdir('/home/ubuntu/gfav/data/phase3/rgb_frames_int/' + dir_name)
# rgb_list.sort()
# # %matplotlib notebook
# cmap = plt.cm.jet
# for rgb_filename in rgb_list:
#     if rgb_filename[-3:] !='jpg':
#         continue
#     rgb_image = cv2.imread('/home/ubuntu/gfav/data/phase3/rgb_frames_int/' + dir_name + rgb_filename)
#     rgb_crop = rgb_image[426:1741, 1001:2776, :].copy()
#     ind = int(rgb_filename[-9:-4])
#     tiff_image = plt.imread('/home/ubuntu/gfav/data/phase3/tiff_frames/' + dir_name + 'frame' + \
#                             format(int((90*ind + 1)/0.99), '05d') + '.tiff')
#     print(tiff_image.min(), tiff_image.max())
#     norm = plt.Normalize(vmin, vmax)
#     tiff_image = cmap(norm(tiff_image))
# #     tiff_image = cmap(tiff_image)
#     # save the image
#     plt.imsave('/home/ubuntu/gfav/data/phase3/ir_frames/' + dir_name + rgb_filename, tiff_image)
#     ir_image = cv2.imread('/home/ubuntu/gfav/data/phase3/ir_frames/' + dir_name + rgb_filename)
#     ir_resize = cv2.resize(ir_image, (rgb_crop.shape[1], rgb_crop.shape[0]))
#     cv2.imwrite('/home/ubuntu/gfav/data/phase3/ir_frames/' + dir_name + rgb_filename, ir_resize)
#     cv2.imwrite('/home/ubuntu/gfav/data/phase3/rgb_frames_crop/' + dir_name + rgb_filename, rgb_crop)
#     figure(num=None, figsize=(8, 6), dpi=100, facecolor='w', edgecolor='k')
#     plt.subplot(1, 2, 1)
#     plt.imshow(cv2.cvtColor(rgb_crop, cv2.COLOR_BGR2RGB))
#     plt.subplot(1, 2, 2)
#     plt.imshow(cv2.cvtColor(ir_resize, cv2.COLOR_BGR2RGB))
#     plt.show()
# #     break

# %%
vmin = 10000
vmax = 0
vminlist = []
vmaxlist = []
dir_list = os.listdir('/home/ubuntu/gfav/data/phase3/tiff_frames/')
for dir_name in dir_list:
    if dir_name!= 'DJI_3007_0':
        continue
    vmin = 10000
    vmax = 0
    if dir_name[:3] != 'DJI':
        continue
    tiff_list = os.listdir('/home/ubuntu/gfav/data/phase3/tiff_frames/' + dir_name + '/')
    for tiff_image_name in tiff_list:
        if tiff_image_name[-4:] != 'tiff':
            continue
        tiff_image = plt.imread('/home/ubuntu/gfav/data/phase3/tiff_frames/' + dir_name + '/' + tiff_image_name)
        vminlist.append(tiff_image.min())
        vmaxlist.append(tiff_image.max())
        if tiff_image.min() < vmin:
            vmin = tiff_image.min()
        if tiff_image.max() > vmax:
            vmax = tiff_image.max()
    print(vmin, vmax, dir_name)
# Out:
# 2054 3728 DJI_3007_0

# %%
histt = plt.hist(vminlist, bins=20)
thresh = 0.05 * np.sum(histt[0])
bins = 20
summ = 0
vmin = 0
for i in range(bins):
    summ += histt[0][i]
    if summ >= thresh:
        vmin = int(histt[1][i])
        print('vmin:', vmin)
        break
# Out:
# vmin: 2066

# %%
histt = plt.hist(vmaxlist, bins=20)
thresh = 0.05 * np.sum(histt[0])
bins = 20
summ = 0
vmax = 0
for i in range(bins-1, -1, -1):
    summ += histt[0][i]
    if summ >= thresh:
        vmax = int(histt[1][i])
        print('vmax:', vmax)
        break
# Out:
# vmax: 2792

# %%
# dir_name = 'DJI_3007_0/'
# tiff_list = os.listdir('/home/ubuntu/gfav/data/phase3/tiff_frames/' + dir_name)
# tiff_list.sort()
# rgb_list = os.listdir('/home/ubuntu/gfav/data/phase3/rgb_frames_int/' + dir_name)
# rgb_list.sort()
# # %matplotlib notebook
# cmap = plt.cm.jet
# for rgb_filename in rgb_list:
#     if rgb_filename[-3:] !='jpg':
#         continue
#     rgb_image = cv2.imread('/home/ubuntu/gfav/data/phase3/rgb_frames_int/' + dir_name + rgb_filename)
#     rgb_crop = rgb_image[426:1741, 1001:2776, :].copy()
#     ind = int(rgb_filename[-9:-4])
#     tiff_image = plt.imread('/home/ubuntu/gfav/data/phase3/tiff_frames/' + dir_name + 'frame' + \
#                             format(int((90*ind + 1)/0.99), '05d') + '.tiff')
#     print(tiff_image.min(), tiff_image.max())
#     norm = plt.Normalize(vmin, vmax)
#     tiff_image = cmap(norm(tiff_image))
# #     tiff_image = cmap(tiff_image)
#     # save the image
#     plt.imsave('/home/ubuntu/gfav/data/phase3/ir_frames/' + dir_name + rgb_filename, tiff_image)
#     ir_image = cv2.imread('/home/ubuntu/gfav/data/phase3/ir_frames/' + dir_name + rgb_filename)
#     ir_resize = cv2.resize(ir_image, (rgb_crop.shape[1], rgb_crop.shape[0]))
#     cv2.imwrite('/home/ubuntu/gfav/data/phase3/ir_frames/' + dir_name + rgb_filename, ir_resize)
#     cv2.imwrite('/home/ubuntu/gfav/data/phase3/rgb_frames_crop/' + dir_name + rgb_filename, rgb_crop)
#     figure(num=None, figsize=(8, 6), dpi=100, facecolor='w', edgecolor='k')
#     plt.subplot(1, 2, 1)
#     plt.imshow(cv2.cvtColor(rgb_crop, cv2.COLOR_BGR2RGB))
#     plt.subplot(1, 2, 2)
#     plt.imshow(cv2.cvtColor(ir_resize, cv2.COLOR_BGR2RGB))
#     plt.show()

# %%
vmin = 10000
vmax = 0
vminlist = []
vmaxlist = []
dir_list = os.listdir('/home/ubuntu/gfav/data/phase3/tiff_frames/')
for dir_name in dir_list:
    if dir_name!= 'DJI_3009_0':
        continue
    vmin = 10000
    vmax = 0
    if dir_name[:3] != 'DJI':
        continue
    tiff_list = os.listdir('/home/ubuntu/gfav/data/phase3/tiff_frames/' + dir_name + '/')
    for tiff_image_name in tiff_list:
        if tiff_image_name[-4:] != 'tiff':
            continue
        tiff_image = plt.imread('/home/ubuntu/gfav/data/phase3/tiff_frames/' + dir_name + '/' + tiff_image_name)
        vminlist.append(tiff_image.min())
        vmaxlist.append(tiff_image.max())
        if tiff_image.min() < vmin:
            vmin = tiff_image.min()
        if tiff_image.max() > vmax:
            vmax = tiff_image.max()
    print(vmin, vmax, dir_name)
# Out:
# 1939 2916 DJI_3009_0

# %%
histt = plt.hist(vminlist, bins=20)
thresh = 0.05 * np.sum(histt[0])
bins = 20
summ = 0
vmin = 0
for i in range(bins):
    summ += histt[0][i]
    if summ >= thresh:
        vmin = int(histt[1][i])
        print('vmin:', vmin)
        break
# Out:
# vmin: 1980

# %%
histt = plt.hist(vmaxlist, bins=20)
thresh = 0.05 * np.sum(histt[0])
bins = 20
summ = 0
vmax = 0
for i in range(bins-1, -1, -1):
    summ += histt[0][i]
    if summ >= thresh:
        vmax = int(histt[1][i])
        print('vmax:', vmax)
        break
# Out:
# vmax: 2672

# %%
# dir_name = 'DJI_3009_0/'
# tiff_list = os.listdir('/home/ubuntu/gfav/data/phase3/tiff_frames/' + dir_name)
# tiff_list.sort()
# rgb_list = os.listdir('/home/ubuntu/gfav/data/phase3/rgb_frames_int/' + dir_name)
# rgb_list.sort()
# # %matplotlib notebook
# cmap = plt.cm.jet
# for rgb_filename in rgb_list:
#     if rgb_filename[-3:] !='jpg':
#         continue
#     rgb_image = cv2.imread('/home/ubuntu/gfav/data/phase3/rgb_frames_int/' + dir_name + rgb_filename)
#     rgb_crop = rgb_image[426:1741, 1001:2776, :].copy()
#     ind = int(rgb_filename[-9:-4])
#     tiff_image = plt.imread('/home/ubuntu/gfav/data/phase3/tiff_frames/' + dir_name + 'frame' + \
#                             format(int((90*ind + 1)/0.99), '05d') + '.tiff')
#     print(tiff_image.min(), tiff_image.max())
#     norm = plt.Normalize(vmin, vmax)
#     tiff_image = cmap(norm(tiff_image))
# #     tiff_image = cmap(tiff_image)
#     # save the image
#     plt.imsave('/home/ubuntu/gfav/data/phase3/ir_frames/' + dir_name + rgb_filename, tiff_image)
#     ir_image = cv2.imread('/home/ubuntu/gfav/data/phase3/ir_frames/' + dir_name + rgb_filename)
#     ir_resize = cv2.resize(ir_image, (rgb_crop.shape[1], rgb_crop.shape[0]))
#     cv2.imwrite('/home/ubuntu/gfav/data/phase3/ir_frames/' + dir_name + rgb_filename, ir_resize)
#     cv2.imwrite('/home/ubuntu/gfav/data/phase3/rgb_frames_crop/' + dir_name + rgb_filename, rgb_crop)
#     figure(num=None, figsize=(8, 6), dpi=100, facecolor='w', edgecolor='k')
#     plt.subplot(1, 2, 1)
#     plt.imshow(cv2.cvtColor(rgb_crop, cv2.COLOR_BGR2RGB))
#     plt.subplot(1, 2, 2)
#     plt.imshow(cv2.cvtColor(ir_resize, cv2.COLOR_BGR2RGB))
#     plt.show()

# %%
vmin = 10000
vmax = 0
vminlist = []
vmaxlist = []
dir_list = os.listdir('/home/ubuntu/gfav/data/phase3/tiff_frames/')
for dir_name in dir_list:
    if dir_name!= 'DJI_3010_0':
        continue
    vmin = 10000
    vmax = 0
    if dir_name[:3] != 'DJI':
        continue
    tiff_list = os.listdir('/home/ubuntu/gfav/data/phase3/tiff_frames/' + dir_name + '/')
    for tiff_image_name in tiff_list:
        if tiff_image_name[-4:] != 'tiff':
            continue
        tiff_image = plt.imread('/home/ubuntu/gfav/data/phase3/tiff_frames/' + dir_name + '/' + tiff_image_name)
        vminlist.append(tiff_image.min())
        vmaxlist.append(tiff_image.max())
        if tiff_image.min() < vmin:
            vmin = tiff_image.min()
        if tiff_image.max() > vmax:
            vmax = tiff_image.max()
    print(vmin, vmax, dir_name)
# Out:
# 2020 2514 DJI_3010_0

# %%
histt = plt.hist(vminlist, bins=20)
thresh = 0.05 * np.sum(histt[0])
bins = 20
summ = 0
vmin = 0
for i in range(bins):
    summ += histt[0][i]
    if summ >= thresh:
        vmin = int(histt[1][i])
        print('vmin:', vmin)
        break
# Out:
# vmin: 2046

# %%
histt = plt.hist(vmaxlist, bins=20)
thresh = 0.05 * np.sum(histt[0])
bins = 20
summ = 0
vmax = 0
for i in range(bins-1, -1, -1):
    summ += histt[0][i]
    if summ >= thresh:
        vmax = int(histt[1][i])
        print('vmax:', vmax)
        break
# Out:
# vmax: 2406

# %%
# dir_name = 'DJI_3010_0/'
# tiff_list = os.listdir('/home/ubuntu/gfav/data/phase3/tiff_frames/' + dir_name)
# tiff_list.sort()
# rgb_list = os.listdir('/home/ubuntu/gfav/data/phase3/rgb_frames_int/' + dir_name)
# rgb_list.sort()
# # %matplotlib notebook
# cmap = plt.cm.jet
# for rgb_filename in rgb_list:
#     if rgb_filename[-3:] !='jpg':
#         continue
#     rgb_image = cv2.imread('/home/ubuntu/gfav/data/phase3/rgb_frames_int/' + dir_name + rgb_filename)
#     rgb_crop = rgb_image[426:1741, 1001:2776, :].copy()
#     ind = int(rgb_filename[-9:-4])
#     tiff_image = plt.imread('/home/ubuntu/gfav/data/phase3/tiff_frames/' + dir_name + 'frame' + \
#                             format(int((90*ind + 1)/0.99), '05d') + '.tiff')
#     print(tiff_image.min(), tiff_image.max())
#     norm = plt.Normalize(vmin, vmax)
#     tiff_image = cmap(norm(tiff_image))
# #     tiff_image = cmap(tiff_image)
#     # save the image
#     plt.imsave('/home/ubuntu/gfav/data/phase3/ir_frames/' + dir_name + rgb_filename, tiff_image)
#     ir_image = cv2.imread('/home/ubuntu/gfav/data/phase3/ir_frames/' + dir_name + rgb_filename)
#     ir_resize = cv2.resize(ir_image, (rgb_crop.shape[1], rgb_crop.shape[0]))
#     cv2.imwrite('/home/ubuntu/gfav/data/phase3/ir_frames/' + dir_name + rgb_filename, ir_resize)
#     cv2.imwrite('/home/ubuntu/gfav/data/phase3/rgb_frames_crop/' + dir_name + rgb_filename, rgb_crop)
#     figure(num=None, figsize=(8, 6), dpi=100, facecolor='w', edgecolor='k')
#     plt.subplot(1, 2, 1)
#     plt.imshow(cv2.cvtColor(rgb_crop, cv2.COLOR_BGR2RGB))
#     plt.subplot(1, 2, 2)
#     plt.imshow(cv2.cvtColor(ir_resize, cv2.COLOR_BGR2RGB))
#     plt.show()

# %%
vmin = 10000
vmax = 0
vminlist = []
vmaxlist = []
dir_list = os.listdir('/home/ubuntu/gfav/data/phase3/tiff_frames/')
for dir_name in dir_list:
    if dir_name!= 'DJI_3011_0':
        continue
    vmin = 10000
    vmax = 0
    if dir_name[:3] != 'DJI':
        continue
    tiff_list = os.listdir('/home/ubuntu/gfav/data/phase3/tiff_frames/' + dir_name + '/')
    for tiff_image_name in tiff_list:
        if tiff_image_name[-4:] != 'tiff':
            continue
        tiff_image = plt.imread('/home/ubuntu/gfav/data/phase3/tiff_frames/' + dir_name + '/' + tiff_image_name)
        vminlist.append(tiff_image.min())
        vmaxlist.append(tiff_image.max())
        if tiff_image.min() < vmin:
            vmin = tiff_image.min()
        if tiff_image.max() > vmax:
            vmax = tiff_image.max()
    print(vmin, vmax, dir_name)
# Out:
# 2014 2520 DJI_3011_0

# %%
histt = plt.hist(vminlist, bins=20)
thresh = 0.05 * np.sum(histt[0])
bins = 20
summ = 0
vmin = 0
for i in range(bins):
    summ += histt[0][i]
    if summ >= thresh:
        vmin = int(histt[1][i])
        print('vmin:', vmin)
        break
# Out:
# vmin: 2040

# %%
histt = plt.hist(vmaxlist, bins=20)
thresh = 0.05 * np.sum(histt[0])
bins = 20
summ = 0
vmax = 0
for i in range(bins-1, -1, -1):
    summ += histt[0][i]
    if summ >= thresh:
        vmax = int(histt[1][i])
        print('vmax:', vmax)
        break
# Out:
# vmax: 2496

# %%
# dir_name = 'DJI_3011_0/'
# tiff_list = os.listdir('/home/ubuntu/gfav/data/phase3/tiff_frames/' + dir_name)
# tiff_list.sort()
# rgb_list = os.listdir('/home/ubuntu/gfav/data/phase3/rgb_frames_int/' + dir_name)
# rgb_list.sort()
# # %matplotlib notebook
# cmap = plt.cm.jet
# for rgb_filename in rgb_list:
#     if rgb_filename[-3:] !='jpg':
#         continue
#     rgb_image = cv2.imread('/home/ubuntu/gfav/data/phase3/rgb_frames_int/' + dir_name + rgb_filename)
#     rgb_crop = rgb_image[426:1741, 1001:2776, :].copy()
#     ind = int(rgb_filename[-9:-4])
#     tiff_image = plt.imread('/home/ubuntu/gfav/data/phase3/tiff_frames/' + dir_name + 'frame' + \
#                             format(int((90*ind + 1)/0.99), '05d') + '.tiff')
#     print(tiff_image.min(), tiff_image.max())
#     norm = plt.Normalize(vmin, vmax)
#     tiff_image = cmap(norm(tiff_image))
# #     tiff_image = cmap(tiff_image)
#     # save the image
#     plt.imsave('/home/ubuntu/gfav/data/phase3/ir_frames/' + dir_name + rgb_filename, tiff_image)
#     ir_image = cv2.imread('/home/ubuntu/gfav/data/phase3/ir_frames/' + dir_name + rgb_filename)
#     ir_resize = cv2.resize(ir_image, (rgb_crop.shape[1], rgb_crop.shape[0]))
#     cv2.imwrite('/home/ubuntu/gfav/data/phase3/ir_frames/' + dir_name + rgb_filename, ir_resize)
#     cv2.imwrite('/home/ubuntu/gfav/data/phase3/rgb_frames_crop/' + dir_name + rgb_filename, rgb_crop)
#     figure(num=None, figsize=(8, 6), dpi=100, facecolor='w', edgecolor='k')
#     plt.subplot(1, 2, 1)
#     plt.imshow(cv2.cvtColor(rgb_crop, cv2.COLOR_BGR2RGB))
#     plt.subplot(1, 2, 2)
#     plt.imshow(cv2.cvtColor(ir_resize, cv2.COLOR_BGR2RGB))
#     plt.show()
